# %% [markdown]
# <a href="https://colab.research.google.com/github/DimitrisZarmpoutis/Python-1/blob/main/12_Monod_Equation_proper_parameters_based_on_lotca_voltera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.integrate as integrate
from scipy.integrate import odeint
import matplotlib.pylab as plt

# %%
def f(r,t):
  Mmax=1.35
  S=0.000022
  Ks=3.76
  Yg=0.4036
  M = 4
  S = 5
  dMdt=(S/(Ks+S))*M*Mmax
  dSdt=-M*S/Yg
  return [dMdt,dSdt]
  np
t = np.linspace (0, 15, 1000)
r0=[20,40]
MS0=np.array([M0,S0])
r=odeint(f,r0,t)
plt.plot (t, r[:,0], 'g-', label='growth rate') # Plot
plt.plot (t, r[:,1], 'b-', label='concentration of the limiting substrate')
p.grid()
p.legend(loc='best')
plt.xlabel ('concentration of the limiting substrate')
plt.ylabel ('growth rate')
plt.title ('Monod Equation')
plt.show()# To display the figure
